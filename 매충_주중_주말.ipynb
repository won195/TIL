# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/%EB%A7%A4%EC%B6%A9_%EC%A3%BC%EC%A4%91_%EC%A3%BC%EB%A7%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/drive/MyDrive/상권분석/추정매출_adm.csv')
df1
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300032
# 2          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 3          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300028
# 4          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300026
# ...         ...       ...      ...        ...      ...          ...       ...
# 735045     2018         4        R       전통시장  2130026      소공지하도상가  CS300011
# 735046     2018         4        R       전통시장  2130026      소공지하도상가  CS300015
# 735047     2018         4        R       전통시장  2130026      소공지하도상가  CS300016
# 735048     2018         4        R       전통시장  2130026      소공지하도상가  CS300017
# 735049     2018         4        R       전통시장  2130026      소공지하도상가  CS300036
#
# ...

# %%
df1 = df1[df1['서비스_업종_코드_명'].isin(['치킨전문점', '양식음식점', '일식음식점', '패스트푸드점', '커피-음료', '호프-간이주점', '한식음식점', '제과점', '중식음식점', '분식전문점'])]

# %%
df1 = df1[df1['기준_분기_코드']==4]

# %%
df1 = df1[df1['기준_년_코드']==2022]

# %%
df1
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 25         2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS100010
# 26         2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS100008
# 27         2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS100006
# 28         2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS100005
# 29         2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS100004
# ...         ...       ...      ...        ...      ...          ...       ...
# 134385     2022         4        A       골목상권  2110002      독립문역 1번  CS100001
# 134453     2022         4        A       골목상권  2110001       이북5도청사  CS100010
# 134454     2022         4        A       골목상권  2110001       이북5도청사  CS100009
# 134455     2022         4        A       골목상권  2110001       이북5도청사  CS100008
# 134456     2022         4        A       골목상권  2110001       이북5도청사  CS100001
#
# ...

# %%
df1['주중_주말_매출_건수'] = df1['주중_매출_건수'] + df1['주말_매출_건수']
# Out:
# <ipython-input-12-1d986ae97df6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['주중_주말_매출_건수'] = df1['주중_매출_건수'] + df1['주말_매출_건수']

# %%
df1.to_csv('/content/drive/MyDrive/상권분석/추정매출/주중_주말_매출_건수_추가.csv')
