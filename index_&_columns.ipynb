# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/index_%26_columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df1 = pd.read_excel('/content/drive/MyDrive/python/데이터스테이션/data/E13EXAMPLE.xlsx', sheet_name=1).set_index('제품')
df1.head()
# Out:
#                수량
# 제품
# 아몬드쿠키 (150g)   40
# 새우육젓 (200g)   200
# 개암염 (250g)     70
# 신안천일염 (5kg)   140
# 베이킹소다 (700g)   60

# %%
df2 = pd.read_excel('/content/drive/MyDrive/python/데이터스테이션/data/E13EXAMPLE.xlsx', sheet_name=2).set_index('제품')
df2.head()
# Out:
#               수량
# 제품
# 새우육젓 (200g)  270
# 개암염 (250g)    70
# 전복죽 (250g)   130
# 신안천일염 (5kg)  130
# 오징어 (420g)   290

# %%
df3 = df2.sub(df1,fill_value=0)
df3.loc[df3['수량'] != 0 ].head(3)
# Out:
#                  수량
# 제품
# 골드손당면 (300g)  110.0
# 곰돌이 (70g)    -180.0
# 내추럴버블껌 (20g)  -70.0
