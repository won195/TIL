# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/ETF_%EC%A0%84%EC%A2%85%EB%AA%A9_%EB%B8%8C%EB%9D%BC%EC%9A%B0%EC%A0%80%EC%9D%98_%EB%84%A4%ED%8A%B8%EC%9B%8C%ED%81%AC_%ED%83%AD%EC%9D%84_%EC%9D%B4%ED%95%B4%ED%95%98%EB%A9%B4_%EC%BD%94%EB%93%9C_%ED%95%9C_%EC%A4%84%EB%A1%9C_%EA%B0%80%EB%8A%A5%ED%95%98%EB%8B%A4%3F!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests

# %%
url = 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'
url
# Out:
# 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# response.json()

# %%
etf_json = response.json()

# %%
etfItemList = etf_json["result"]["etfItemList"]

# %%
len(etfItemList)
# Out:
# 788

# %%
df = pd.DataFrame(etfItemList)
df.shape
# Out:
# (788, 12)

# %%
df.head()
# Out:
#   itemcode  etfTabCode              itemname   nowVal risefall  changeVal  \
# 0   357870           6   TIGER CD금리투자KIS(합성)    53205        2          5
# 1   069500           1             KODEX 200    31840        5       -175
# 2   423160           6   KODEX KOFR금리액티브(합성)   104655        2         10
# 3   459580           6     KODEX CD금리액티브(합성)  1015225        2        100
# 4   273130           6  KODEX 종합채권(AA-이상)액티브   103250        5        -85
#
#    changeRate        nav  threeMonthEarnRate    quant  amonut  marketSum
# 0        0.01    53209.0              0.9200   104324    5550      70254
# 1       -0.55    31866.0             -7.2970  2893689   92495      58665
# 2        0.01   104653.0              0.9161   529214   55382      40399
# 3        0.01  1015220.0              0.9336    83463   84733      34044
# 4       -0.08   103336.0             -1.7729     1809     186      27135

# %%
df.tail()
# Out:
#     itemcode  etfTabCode             itemname  nowVal risefall  changeVal  \
# 783   252000           1        TIGER 200동일가중   10110        2        195
# 784   287300           2         KBSTAR 200건설   12085        2          5
# 785   287330           2      KBSTAR 200생활소비재    5735        2        125
# 786   315480           2  KBSTAR 200커뮤니케이션서비스    9780        5        -35
# 787   287320           2        KBSTAR 200산업재   10300        5       -280
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 783        1.97  10105.0             -7.8532      2       0         15
# 784        0.04  12130.0            -14.9895     24       0         15
# 785        2.23   5749.0              0.8086    299       1         13
# 786       -0.36   9811.0             -7.3620    466       4         12
# 787       -2.65  10327.0            -14.4705     29       0         10

# %%
import datetime
today = datetime.datetime.today()
today = today.strftime("%Y-%m-%d")
today
# Out:
# '2023-10-25'

# %%
file_name = f"etf_{today}_raw.csv"
file_name
# Out:
# 'etf_2023-10-25_raw.csv'

# %%
df.to_csv(file_name, index=False)

# %%
pd.read_csv(file_name, dtype={"itemcode":np.object})
