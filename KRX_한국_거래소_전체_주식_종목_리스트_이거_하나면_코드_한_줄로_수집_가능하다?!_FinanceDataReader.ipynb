# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/KRX_%ED%95%9C%EA%B5%AD_%EA%B1%B0%EB%9E%98%EC%86%8C_%EC%A0%84%EC%B2%B4_%EC%A3%BC%EC%8B%9D_%EC%A2%85%EB%AA%A9_%EB%A6%AC%EC%8A%A4%ED%8A%B8_%EC%9D%B4%EA%B1%B0_%ED%95%98%EB%82%98%EB%A9%B4_%EC%BD%94%EB%93%9C_%ED%95%9C_%EC%A4%84%EB%A1%9C_%EC%88%98%EC%A7%91_%EA%B0%80%EB%8A%A5%ED%95%98%EB%8B%A4%3F!_FinanceDataReader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.50-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.31.0)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2023.7.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->finance-datareader) (1.16.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.50 requests-file-1.5.1

# %%
import pandas as pd
import FinanceDataReader as fdr

# %%
df = fdr.DataReader("005930", "2019")
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2019-01-02  39400  39400  38550  38750   7847664  0.001292
# 2019-01-03  38300  38550  37450  37600  12471493 -0.029677
# 2019-01-04  37450  37600  36850  37450  14108958 -0.003989
# 2019-01-07  38000  38900  37800  38750  12748997  0.034713
# 2019-01-08  38000  39200  37950  38100  12756554 -0.016774

# %%
df["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2762 entries, 0 to 2761
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         2762 non-null   object
#  1   ISU_CD       2762 non-null   object
#  2   Name         2762 non-null   object
#  3   Market       2762 non-null   object
#  4   Dept         2762 non-null   object
#  5   Close        2762 non-null   object
#  6   ChangeCode   2762 non-null   object
#  7   Changes      2762 non-null   int64
#  8   ChagesRatio  2762 non-null   float64
#  9   Open         2762 non-null   int64
#  10  High         2762 non-null   int64
#  11  Low          2762 non-null   int64
#  12  Volume       2762 non-null   int64
#  13  Amount       2762 non-null   int64
#  14  Marcap       2762 non-null   int64
#  15  Stocks       2762 non-null   int64
#  16  MarketId     2762 non-null   object
# dtypes: float64(1), int64(8), object(8)
# memory usage: 367.0+ KB

# %%
df_krx.describe(include='all')
# Out:
#           Code        ISU_CD  Name  Market  Dept Close ChangeCode  \
# count     2762          2762  2762    2762  2762  2762       2762
# unique    2762          2762  2762       4    10  1941          6
# top     005930  KR7005930003  삼성전자  KOSDAQ        2070          1
# freq         1             1     1    1632   952     7       2002
# mean       NaN           NaN   NaN     NaN   NaN   NaN        NaN
# std        NaN           NaN   NaN     NaN   NaN   NaN        NaN
# min        NaN           NaN   NaN     NaN   NaN   NaN        NaN
# 25%        NaN           NaN   NaN     NaN   NaN   NaN        NaN
# 50%        NaN           NaN   NaN     NaN   NaN   NaN        NaN
# 75%        NaN           NaN   NaN     NaN   NaN   NaN        NaN
# max        NaN           NaN   NaN     NaN   NaN   NaN        NaN
#
#              Changes  ChagesRatio           Open           High  \
# count    2762.000000  2762.000000    2762.000000    2762.000000
# unique           NaN          NaN            NaN            NaN
# top              NaN          NaN            NaN            NaN
# freq             NaN          NaN            NaN            NaN
# mean      288.976828     1.798805   18201.142288   18603.683563
# std      1355.552579     3.417079   46982.497197   47823.097282
# min    -10000.000000   -16.780000       0.000000       0.000000
# 25%         0.000000     0.000000    2275.000000    2321.250000
# 50%        60.500000     1.460000    5570.000000    5785.000000
# 75%       240.000000     3.227500   14185.000000   14672.500000
# max     38000.000000    30.000000  736000.000000  758000.000000
#
#                   Low        Volume        Amount        Marcap        Stocks  \
# count     2762.000000  2.762000e+03  2.762000e+03  2.762000e+03  2.762000e+03
# unique            NaN           NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN           NaN
# mean     17683.260319  5.055324e+05  5.414548e+09  8.277058e+11  4.156723e+07
# std      45554.505277  2.489431e+06  3.003976e+10  8.636075e+12  1.327790e+08
# min          0.000000  0.000000e+00  0.000000e+00  1.231677e+09  1.535360e+05
# 25%       2200.000000  1.839575e+04  9.329723e+07  5.290590e+10  1.010261e+07
# 50%       5390.000000  7.205000e+04  3.871622e+08  1.066115e+11  1.973274e+07
# 75%      13895.000000  2.379868e+05  1.822592e+09  2.659620e+11  4.150875e+07
# max     707000.000000  6.175517e+07  8.741483e+11  4.089301e+14  5.969783e+09
#
#        MarketId
# count      2762
# unique        3
# top         KSQ
# freq       1682
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df_krx.to_csv("/content/drive/MyDrive/오늘코드todaycode/data/krx.csv", index=False)

# %%
df_krx = pd.read_csv("krx.csv")

# %%
df_krx.shape
# Out:
# (2762, 17)

# %%
df_krx[["Code", "Name"]].head()
# Out:
#      Code      Name
# 0  005930      삼성전자
# 1  373220  LG에너지솔루션
# 2  000660    SK하이닉스
# 3  207940  삼성바이오로직스
# 4  005935     삼성전자우

# %%
#df_krx[df_krx["Code"]=="352820"]
df_krx.loc[df_krx["Name"]=="하이브", "Code"].tolist()[0]
# Out:
# '352820'

# %%
def item_code_by_item_name(item_name):
  item_code_list = df_krx.loc[df_krx["Name"]==item_name, "Code"].tolist()[0]
  if len(item_code_list) > 0:
    return item_code_list
  else:
    return False

# %%
item_code_by_item_name("하이브")
# Out:
# '352820'

# %%
item_code_by_item_name("NAVER")
# Out:
# '035420'

# %%
item_code_by_item_name("삼성전자")
# Out:
# '005930'
