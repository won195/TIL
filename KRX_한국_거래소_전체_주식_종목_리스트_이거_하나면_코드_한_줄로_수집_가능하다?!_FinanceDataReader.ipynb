# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/KRX_%ED%95%9C%EA%B5%AD_%EA%B1%B0%EB%9E%98%EC%86%8C_%EC%A0%84%EC%B2%B4_%EC%A3%BC%EC%8B%9D_%EC%A2%85%EB%AA%A9_%EB%A6%AC%EC%8A%A4%ED%8A%B8_%EC%9D%B4%EA%B1%B0_%ED%95%98%EB%82%98%EB%A9%B4_%EC%BD%94%EB%93%9C_%ED%95%9C_%EC%A4%84%EB%A1%9C_%EC%88%98%EC%A7%91_%EA%B0%80%EB%8A%A5%ED%95%98%EB%8B%A4%3F!_FinanceDataReader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install finance-datareader

# %%
import pandas as pd
import FinanceDataReader as fdr

# %%
df = fdr.DataReader("005930", "2019")
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2019-01-02  39400  39400  38550  38750   7847664  0.001292
# 2019-01-03  38300  38550  37450  37600  12471493 -0.029677
# 2019-01-04  37450  37600  36850  37450  14108958 -0.003989
# 2019-01-07  38000  38900  37800  38750  12748997  0.034713
# 2019-01-08  38000  39200  37950  38100  12756554 -0.016774

# %%
df["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_krx.to_csv("/content/drive/MyDrive/오늘코드todaycode/data/krx.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-26ced3dcc1d1> in <cell line: 1>()
# ----> 1 df_krx.to_csv("/content/drive/MyDrive/오늘코드todaycode/data/krx.csv", index=False)
#
# NameError: name 'df_krx' is not defined

# %%
df_krx = pd.read_csv("/content/drive/MyDrive/오늘코드todaycode/data/krx.csv")

# %%
df_krx.shape
# Out:
# (2762, 17)

# %%
df_krx[["Code", "Name"]].head()
# Out:
#      Code      Name
# 0  005930      삼성전자
# 1  373220  LG에너지솔루션
# 2  000660    SK하이닉스
# 3  207940  삼성바이오로직스
# 4  005935     삼성전자우

# %%
#df_krx[df_krx["Code"]=="352820"]
df_krx.loc[df_krx["Name"]=="하이브", "Code"].tolist()[0]
# Out:
# '352820'

# %%
def item_code_by_item_name(item_name):
  item_code_list = df_krx.loc[df_krx["Name"]==item_name, "Code"].tolist()[0]
  if len(item_code_list) > 0:
    return item_code_list
  else:
    return False

# %%
item_code_by_item_name("하이브")
# Out:
# '352820'

# %%
item_code_by_item_name("NAVER")
# Out:
# '035420'

# %%
item_code_by_item_name("삼성전자")
# Out:
# '005930'

# %%
item_code_by_item_name("셀트리온")
# Out:
# '068270'

# %%
item_code_by_item_name("카카오게임즈")
# Out:
# '293490'

# %%
fdr.DataReader(item_code_by_item_name("LG화학"))
# Out:
#               Open    High     Low   Close   Volume    Change
# Date
# 2001-04-25   20621   20621   17563   18489  3094940       NaN
# 2001-04-26   17918   18416   17492   17636  1197840 -0.046136
# 2001-04-27   17280   18204   17066   18062   854340  0.024155
# 2001-04-30   17706   18275   17706   18204   803230  0.007862
# 2001-05-02   18345   18843   17990   18489   851580  0.015656
# ...            ...     ...     ...     ...      ...       ...
# 2023-10-19  491000  498500  488500  494000   462488 -0.023715
# 2023-10-20  485000  487000  475000  479000   349050 -0.030364
# 2023-10-23  475000  489000  469000  481000   292347  0.004175
# 2023-10-24  481000  494000  463000  492000   340115  0.022869
# 2023-10-25  489000  489000  465500  466000   250234 -0.052846
#
# [5561 rows x 6 columns]

# %%
def find_item_list(item_name, year=2020):
  item_code = item_code_by_item_name(item_name)
  if item_code:
    df_day = fdr.DataReader(item_code, str(year))
    return df_day
  else:
    return False

# %%
find_item_list("NAVER")
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2020-01-02  187500  188000  182000  182500  300640 -0.021448
# 2020-01-03  185000  186000  180500  181500  454492 -0.005479
# 2020-01-06  180000  182000  178000  180500  287970 -0.005510
# 2020-01-07  182500  187000  181500  187000  328624  0.036011
# 2020-01-08  182000  183500  179000  183000  820867 -0.021390
# ...            ...     ...     ...     ...     ...       ...
# 2023-10-19  183100  183600  180700  181400  789241 -0.026302
# 2023-10-20  178400  181600  178000  180200  579075 -0.006615
# 2023-10-23  179300  182200  178200  178300  446010 -0.010544
# 2023-10-24  181500  187100  180100  187000  802790  0.048794
# 2023-10-25  189900  191200  184800  189100  722632  0.011230
#
# [942 rows x 6 columns]

# %%
find_item_list("LG화학")
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2020-01-02  321000  321000  313500  314000  139496 -0.011024
# 2020-01-03  317000  318500  310500  311000  165030 -0.009554
# 2020-01-06  308000  311000  306500  307000  138154 -0.012862
# 2020-01-07  306000  313500  305000  311000  133788  0.013029
# 2020-01-08  306000  307000  301500  302000  225471 -0.028939
# ...            ...     ...     ...     ...     ...       ...
# 2023-10-19  491000  498500  488500  494000  462488 -0.023715
# 2023-10-20  485000  487000  475000  479000  349050 -0.030364
# 2023-10-23  475000  489000  469000  481000  292347  0.004175
# 2023-10-24  481000  494000  463000  492000  340115  0.022869
# 2023-10-25  489000  489000  456500  458000  402504 -0.069106
#
# [942 rows x 6 columns]

# %%
stock_daily = find_item_list("하이브")
stock_daily
# Out:
#               Open    High     Low   Close   Volume    Change
# Date
# 2020-10-15  267300  347490  250965  255420  6557212       NaN
# 2020-10-16  250469  250469  197010  198495  4504395 -0.222868
# 2020-10-19  196515  200475  185129  187110  1977996 -0.057357
# 2020-10-20  188100  191565  174240  180675  1811616 -0.034392
# 2020-10-21  178695  183645  175230  177210  1658643 -0.019178
# ...            ...     ...     ...     ...      ...       ...
# 2023-10-19  230000  233500  227000  227500   117136 -0.027778
# 2023-10-20  224000  228000  222000  224500   130309 -0.013187
# 2023-10-23  224500  234500  224500  229000   141201  0.020045
# 2023-10-24  232500  235500  226000  231500   105953  0.010917
# 2023-10-25  233000  235500  227000  228500   140031 -0.012959
#
# [748 rows x 6 columns]

# %%
stock_daily["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stock_daily.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
g = stock_daily.plot(subplots=True, figsize=(10,8))

# %%
h = stock_daily.hist(figsize=(10, 8), bins=20)

# %%
stock_daily[['Close', 'Volume']].plot(secondary_y="Volume")
# Out:
# <Axes: xlabel='Date'>

# %%
stock_daily.describe()
# Out:
#                 Open           High            Low          Close  \
# count     748.000000     748.000000     748.000000     748.000000
# mean   234123.510695  239558.957219  229020.814171  233819.772727
# std     64218.194142   65218.578473   62916.068446   63986.773961
# min    111000.000000  113000.000000  107000.000000  109500.000000
# 25%    176900.000000  180631.250000  173187.500000  177000.000000
# 50%    242000.000000  246007.500000  236750.000000  240785.000000
# 75%    281500.000000  287625.000000  276500.000000  281000.000000
# max    418000.000000  421500.000000  408500.000000  414000.000000
#
#              Volume      Change
# count  7.480000e+02  747.000000
# mean   3.555250e+05    0.000426
# std    4.506796e+05    0.033607
# min    7.409200e+04   -0.248705
# 25%    1.742542e+05   -0.018519
# 50%    2.427230e+05    0.000000
# 75%    3.937865e+05    0.017668
# max    6.557212e+06    0.114625
