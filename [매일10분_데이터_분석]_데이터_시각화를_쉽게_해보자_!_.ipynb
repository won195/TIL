# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/%5B%EB%A7%A4%EC%9D%BC10%EB%B6%84_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D%5D_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94%EB%A5%BC_%EC%89%BD%EA%B2%8C_%ED%95%B4%EB%B3%B4%EC%9E%90_!_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
import pandas as pd
import seaborn as sns

df1 = pd.read_csv('/content/drive/MyDrive/python/데이터스테이션/data/Data03.csv')

df1.head()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
#          id type_of_contract type_of_contract2 channel    datetime  Term  \
# 0  66758234               렌탈            Normal  서비스 방문  2019-10-20    60
# 1  66755948               렌탈  Extension_Rental  서비스 방문  2019-10-20    60
# 2  66756657               렌탈            Normal  홈쇼핑/방송  2019-10-20    60
# 3  66423450              멤버십               TAS   렌탈재계약  2019-10-20    12
# 4  66423204              멤버십               TAS   렌탈재계약  2019-10-20    12
#
#   payment_type product  amount state  overdue_count overdue  credit rating  \
# 0          CMS      K1   96900  계약확정              0      없음            9.0
# 1         카드이체      K1  102900  계약확정              0      없음            2.0
# 2          CMS      K1   96900  계약확정              0      없음            8.0
# 3          CMS      K1   66900  계약확정              0      없음            5.0
# 4          CMS      K1   66900  해약확정             12      있음            8.0
#
#     bank cancellation   age  Mileage
# 0  새마을금고           정상  43.0   1862.0
# 1   현대카드           정상  62.0   2532.0
# 2   우리은행           정상  60.0   2363.0
# 3   농협은행           정상  60.0   2449.0
# 4   농협은행           해약  51.0   1942.0

# %%
df1['type_of_contract'].value_counts()
# Out:
# 렌탈     46481
# 멤버십     4819
# Name: type_of_contract, dtype: int64

# %%
sns.countplot(data=df1, x='type_of_contract')
# Out:
# <Axes: xlabel='type_of_contract', ylabel='count'>
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47116 (\N{HANGUL SYLLABLE REN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 53448 (\N{HANGUL SYLLABLE TAL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47716 (\N{HANGUL SYLLABLE MEM}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49901 (\N{HANGUL SYLLABLE SIB}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47116 (\N{HANGUL SYLLABLE REN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53448 (\N{HANGUL SYLLABLE TAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47716 (\N{HANGUL SYLLABLE MEM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49901 (\N{HANGUL SYLLABLE SIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df1['product'].value_counts()
# Out:
# K1    39134
# K2     8995
# K3     2082
# K5      645
# K4      327
# K6      120
# Name: product, dtype: int64

# %%
sns.countplot(data=df1, x='product',hue='type_of_contract2')
# Out:
# <Axes: xlabel='product', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# !apt-get install -y fonts-nanum
mpl.rc('font', family='Malgun Gothic')
mpl.rc('font', family='NanumBarunGothic')
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
sns.countplot(data=df1, x='type_of_contract')
# Out:
# <Axes: xlabel='type_of_contract', ylabel='count'>

# %%
plt.figure(figsize=[10,5])
sns.countplot(data=df1, x='product',hue='type_of_contract2')
# Out:
# <Axes: xlabel='product', ylabel='count'>

# %%
plt.title('계약 유형 별, 고객 연령 분포')
sns.histplot(data=df1, x='age',kde=True, hue='type_of_contract')
# Out:
# <Axes: title={'center': '계약 유형 별, 고객 연령 분포'}, xlabel='age', ylabel='Count'>

# %%
sns.countplot(data=df1, x='bank')
# Out:
# <Axes: xlabel='bank', ylabel='count'>

# %%
plt.figure(figsize=[5,10])
sns.countplot(data=df1,y='bank')
# Out:
# <Axes: xlabel='count', ylabel='bank'>

# %%
df1['bank'].value_counts()
# Out:
# 국민은행         9901
# 롯데카드         9518
# 농협은행         6278
# 신한은행         3522
# 우리은행         3386
# 기업은행         1963
# 신한카드         1533
# 하나은행         1446
# 국민카드         1311
# BC카드         1264
# 새마을금고         964
# 부산은행          888
# 삼성카드          884
# 현대카드          876
# 대구은행          746
# 우체국           717
# 외환은행          586
# 외환카드          530
# 경남은행          442
# SC제일은행        439
# 광주은행          347
# 신협중앙회         341
# 전북은행          195
# 씨티은행          162
# 수협중앙회         160
# 제주은행           40
# 유안타증권          27
# 산업은행           23
# 현대증권           11
# 삼성증권            7
# 하나SK            6
# 미래에셋증권          5
# NH농협카드          4
# 한국투자증권          4
# 신한금융투자          4
# 우리카드            3
# 대우증권            2
# 하이투자증권          1
# 메리츠종합금융증권       1
# 수협카드            1
# 상호저축은행          1
# SK증권            1
# 하나대투증권          1
# 산림조합중앙회         1
# 대신증권            1
# 씨티카드            1
# Name: bank, dtype: int64

# %%
sns.countplot(data=df1, x='bank',order=['국민은행','롯데카드','농협은행','신한은행'])
# Out:
# <Axes: xlabel='bank', ylabel='count'>

# %%
df1['bank'].value_counts().index.tolist()
# Out:
# ['국민은행',
#  '롯데카드',
#  '농협은행',
#  '신한은행',
#  '우리은행',
#  '기업은행',
#  '신한카드',
#  '하나은행',
#  '국민카드',
#  'BC카드',
#  '새마을금고',
#  '부산은행',
#  '삼성카드',
#  '현대카드',
#  '대구은행',
#  '우체국',
#  '외환은행',
#  '외환카드',
#  '경남은행',
#  'SC제일은행',
#  '광주은행',
#  '신협중앙회',
#  '전북은행',
#  '씨티은행',
#  '수협중앙회',
#  '제주은행',
#  '유안타증권',
#  '산업은행',
#  '현대증권',
#  '삼성증권',
#  '하나SK',
#  '미래에셋증권',
#  'NH농협카드',
#  '한국투자증권',
#  '신한금융투자',
#  '우리카드',
#  '대우증권',
#  '하이투자증권',
#  '메리츠종합금융증권',
#  '수협카드',
#  '상호저축은행',
#  'SK증권',
#  '하나대투증권',
#  '산림조합중앙회',
#  '대신증권',
#  '씨티카드']

# %%
order_list = df1['bank'].value_counts().index.tolist()

# %%
sns.countplot(data=df1, x='bank', order=order_list)
# Out:
# <Axes: xlabel='bank', ylabel='count'>

# %%
sns.countplot(data=df1, x='bank', order=order_list[0:10])
# Out:
# <Axes: xlabel='bank', ylabel='count'>
