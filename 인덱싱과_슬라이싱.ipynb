# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/%EC%9D%B8%EB%8D%B1%EC%8B%B1%EA%B3%BC_%EC%8A%AC%EB%9D%BC%EC%9D%B4%EC%8B%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 = pd.read_excel('/content/drive/MyDrive/python/데이터스테이션/data/E09EXAMPLE.xlsx', skiprows=1)

# %%
df1 = df1.loc[:,'년도':'개최국']
df1.iloc[:, [0, 9, 3, 4, 5, 6]]# to_clipboard(index=False)
# Out:
#       년도           개최국         1위              2위           3위              4위
# 0   1930       Uruguay    Uruguay       Argentina          USA      Yugoslavia
# 1   1934         Italy      Italy  Czechoslovakia      Germany         Austria
# 2   1938        France      Italy         Hungary       Brazil          Sweden
# 3   1950        Brazil    Uruguay          Brazil       Sweden           Spain
# 4   1954   Switzerland    Germany         Hungary      Austria         Uruguay
# 5   1958        Sweden     Brazil          Sweden       France         Germany
# 6   1962         Chile     Brazil  Czechoslovakia        Chile      Yugoslavia
# 7   1966       England    England         Germany     Portugal    Soviet Union
# 8   1970        Mexico     Brazil           Italy      Germany         Uruguay
# 9   1974       Germany    Germany     Netherlands       Poland          Brazil
# 10  1978     Argentina  Argentina     Netherlands       Brazil           Italy
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
