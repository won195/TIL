# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/%EA%B5%AC%EC%BB%AC%EB%9F%BC_%EC%B6%94%EA%B0%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/상권분석/상권영역_주소.csv')
df2 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-상주인구).csv', encoding='cp949')
df3 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-생활인구).csv', encoding='cp949')
df4 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-직장인구).csv', encoding='cp949')
df5 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-추정매출).csv', encoding='cp949')
df6 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권영역).csv', encoding='cp949')

# %%
df1 = df1.rename(columns={'lat': 'long', 'long': 'lat'})

# %%
df1
# Out:
#       기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값  \
# 0       202112        A       골목상권  2110753   시흥동 은행나무사거리  191934  438813
# 1       202112        A       골목상권  2110427    노원 을지대학교병원  206265  459431
# 2       202112        A       골목상권  2110755      동일여자고등학교  192300  439070
# 3       202112        A       골목상권  2110739    시흥3동 우편취급국  191289  438014
# 4       202112        A       골목상권  2111017      송파나루역 3번  210222  445516
# ...        ...      ...        ...      ...           ...     ...     ...
# 1666    202112        U       관광특구  1001493  동대문패션타운 관광특구  200974  451975
# 1667    202112        U       관광특구  1001494    종로?청계 관광특구  199768  452273
# 1668    202112        U       관광특구  1001495       잠실 관광특구  210191  446339
# 1669    202112        U       관광특구  1001496   강남 마이스 관광특구  205310  445727
# 1670    202112        U       관광특구  1001491      이태원 관광특구  199503  448326
#
#       시군구_코드    행정동_코드  형태정보        long        lat    시도명 시군구명         읍면동명  \
# ...

# %%
df2 = df2.rename(columns={'상권 코드': '상권_코드', '상권 코드 명': '상권_코드_명'})

# %%
df2
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  총 상주인구 수  남성 상주인구 수  \
# 0         2022         4        U       관광특구  1001496        29         16
# 1         2022         4        U       관광특구  1001495      9639       4250
# 2         2022         4        U       관광특구  1001494      1977       1303
# 3         2022         4        U       관광특구  1001493      2703       1294
# 4         2022         4        U       관광특구  1001492      1089        403
# ...        ...       ...      ...        ...      ...       ...        ...
# 39173     2017         1        A       골목상권  2110005      1940        941
# 39174     2017         1        A       골목상권  2110004       534        262
# 39175     2017         1        A       골목상권  2110003      3337       1627
# 39176     2017         1        A       골목상권  2110002       680        335
# 39177     2017         1        A       골목상권  2110001      1211        574
#
# ...

# %%
df3.info(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40041 entries, 0 to 40040
# Data columns (total 532 columns):
#  #    Column                       Dtype
# ---   ------                       -----
#  0    기준 년코드                       int64
#  1    기준_분기_코드                     int64
#  2    상권_구분_코드                     object
#  3     상권_구분_코드_명                  object
#  4    상권_코드                        int64
#  5    상권_코드_명                      object
#  6    총_생활인구_수                     int64
#  7    남성_생활인구_수                    int64
#  8    여성_생활인구_수                    int64
#  9    연령대_10_생활인구_수                int64
#  10   연령대_20_생활인구_수                int64
#  11   연령대_30_생활인구_수                int64
#  12   연령대_40_생활인구_수                int64
#  13   연령대_50_생활인구_수                int64
#  14   연령대_60_이상_생활인구_수             int64
#  15   시간대_1_생활인구_수                 int64
#  16   시간대_2_생활인구_수                 int64
#  17   시간대_3_생활인구_수                 int64
# ...

# %%
df3
# Out:
#        기준 년코드  기준_분기_코드 상권_구분_코드  상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0        2022         4        U        관광특구  1001496             강남 마이스 관광특구
# 1        2022         4        U        관광특구  1001495                 잠실 관광특구
# 2        2022         4        U        관광특구  1001494              종로?청계 관광특구
# 3        2022         4        U        관광특구  1001493            동대문패션타운 관광특구
# 4        2022         4        U        관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
# ...       ...       ...      ...         ...      ...                     ...
# 40036    2017         1        A        골목상권  2110005                     세검정
# 40037    2017         1        A        골목상권  2110004                  대신고등학교
# 40038    2017         1        A        골목상권  2110003                 세검정초등학교
# 40039    2017         1        A        골목상권  2110002                 독립문역 1번
# 40040    2017         1        A        골목상권  2110001                  이북5도청사
#
# ...

# %%
df4
# Out:
#        기준_년월_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  \
# 0          2022         4        U       관광특구  1001496
# 1          2022         4        U       관광특구  1001495
# 2          2022         4        U       관광특구  1001494
# 3          2022         4        U       관광특구  1001493
# 4          2022         4        U       관광특구  1001492
# ...         ...       ...      ...        ...      ...
# 37739      2017         2        A       골목상권  2110005
# 37740      2017         2        A       골목상권  2110004
# 37741      2017         2        A       골목상권  2110003
# 37742      2017         2        A       골목상권  2110002
# 37743      2017         2        A       골목상권  2110001
#
#                       상권_코드_명  총_직장_인구_수  남성_직장_인구_수  여성_직장_인구_수  \
# 0                 강남 마이스 관광특구      15904        8904        7000
# 1                     잠실 관광특구      24375       14199       10176
# 2                  종로?청계 관광특구      32935       17150       15785
# ...

# %%
df5
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명 서비스_업종_코드  \
# 0          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300043
# 1          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300032
# 2          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300031
# 3          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300028
# 4          2022         4        U       관광특구  1001496  강남 마이스 관광특구  CS300026
# ...         ...       ...      ...        ...      ...          ...       ...
# 136815     2022         1        A       골목상권  2110001       이북5도청사  CS200001
# 136816     2022         1        A       골목상권  2110001       이북5도청사  CS100010
# 136817     2022         1        A       골목상권  2110001       이북5도청사  CS100009
# 136818     2022         1        A       골목상권  2110001       이북5도청사  CS100008
# 136819     2022         1        A       골목상권  2110001       이북5도청사  CS100001
#
# ...

# %%
df6
# Out:
#       기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값  \
# 0       202112        A       골목상권  2110753   시흥동 은행나무사거리  191934  438813
# 1       202112        A       골목상권  2110427    노원 을지대학교병원  206265  459431
# 2       202112        A       골목상권  2110755      동일여자고등학교  192300  439070
# 3       202112        A       골목상권  2110739    시흥3동 우편취급국  191289  438014
# 4       202112        A       골목상권  2111017      송파나루역 3번  210222  445516
# ...        ...      ...        ...      ...           ...     ...     ...
# 1666    202112        U       관광특구  1001493  동대문패션타운 관광특구  200974  451975
# 1667    202112        U       관광특구  1001494    종로?청계 관광특구  199768  452273
# 1668    202112        U       관광특구  1001495       잠실 관광특구  210191  446339
# 1669    202112        U       관광특구  1001496   강남 마이스 관광특구  205310  445727
# 1670    202112        U       관광특구  1001491      이태원 관광특구  199503  448326
#
#       시군구_코드    행정동_코드  형태정보
# 0      11545  11545710   NaN
# ...

# %%
df2 = pd.merge(df2, df1[['상권_코드', '시군구명', '행정동_코드', '읍면동명', '동리명']], on='상권_코드', how='inner')
df3 = pd.merge(df3, df1[['상권_코드', '시군구명', '행정동_코드', '읍면동명', '동리명']], on='상권_코드', how='inner')
df4 = pd.merge(df4, df1[['상권_코드', '시군구명', '행정동_코드', '읍면동명', '동리명']], on='상권_코드', how='inner')
df5 = pd.merge(df5, df1[['상권_코드', '시군구명', '행정동_코드', '읍면동명', '동리명']], on='상권_코드', how='inner')
df6 = pd.merge(df6, df1[['상권_코드', '시군구명', '행정동_코드', '읍면동명', '동리명']], on='상권_코드', how='inner')

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1671 entries, 0 to 1670
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   기준_년월_코드    1671 non-null   int64
#  1   상권_구분_코드    1671 non-null   object
#  2   상권_구분_코드_명  1671 non-null   object
#  3   상권_코드       1671 non-null   int64
#  4   상권_코드_명     1671 non-null   object
#  5   엑스좌표_값      1671 non-null   int64
#  6   와이좌표_값      1671 non-null   int64
#  7   시군구_코드      1671 non-null   int64
#  8   행정동_코드_x    1671 non-null   int64
#  9   형태정보        0 non-null      float64
#  10  시군구명        1642 non-null   object
#  11  행정동_코드_y    1671 non-null   int64
#  12  읍면동명        1642 non-null   object
#  13  동리명         1642 non-null   object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 195.8+ KB

# %%
df1 = pd.read_csv('/content/drive/MyDrive/상권분석/상권영역_주소.csv')
df2 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-상주인구).csv', encoding='cp949')
df3 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-생활인구).csv', encoding='cp949')
df4 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-직장인구).csv', encoding='cp949')
df5 = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-추정매출).csv', encoding='cp949')

# %%
df2.to_csv('/content/drive/MyDrive/상권분석/(상권-상주인구)_주소추가.csv', index=False)
df3.to_csv('/content/drive/MyDrive/상권분석/(상권-생활인구)_주소추가.csv', index=False)
df4.to_csv('/content/drive/MyDrive/상권분석/(상권-직장인구)_주소추가.csv', index=False)
df5.to_csv('/content/drive/MyDrive/상권분석/(상권-추정매출)_주소추가.csv', index=False)
