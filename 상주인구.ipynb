# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/%EC%83%81%EC%A3%BC%EC%9D%B8%EA%B5%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_csv('/content/drive/MyDrive/상권분석/서울시 우리마을가게 상권분석서비스(상권-상주인구).csv', encoding='cp949')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39178 entries, 0 to 39177
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   기준_년_코드             39178 non-null  int64
#  1   기준_분기_코드            39178 non-null  int64
#  2   상권_구분_코드            39178 non-null  object
#  3   상권_구분_코드_명          39178 non-null  object
#  4   상권 코드               39178 non-null  int64
#  5   총 상주인구 수            39178 non-null  int64
#  6   남성 상주인구 수           39178 non-null  int64
#  7   여성 상주인구 수           39178 non-null  int64
#  8   연령대 10 상주인구 수       39178 non-null  int64
#  9   연령대 20 상주인구 수       39178 non-null  int64
#  10  연령대 30 상주인구 수       39178 non-null  int64
#  11  연령대 40 상주인구 수       39178 non-null  int64
#  12  연령대 50 상주인구 수       39178 non-null  int64
#  13  연령대 60 이상 상주인구 수    39178 non-null  int64
#  14  남성연령대 10 상주인구 수     39178 non-null  int64
#  15  남성연령대 20 상주인구 수     39178 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권 코드', '총 상주인구 수',
#        '남성 상주인구 수', '여성 상주인구 수', '연령대 10 상주인구 수', '연령대 20 상주인구 수',
#        '연령대 30 상주인구 수', '연령대 40 상주인구 수', '연령대 50 상주인구 수', '연령대 60 이상 상주인구 수',
#        '남성연령대 10 상주인구 수', '남성연령대 20 상주인구 수', '남성연령대 30 상주인구 수',
#        '남성연령대 40 상주인구 수', '남성연령대 50 상주인구 수', '남성연령대 60 이상 상주인구 수',
#        '여성연령대 10 상주인구 수', '여성연령대 20 상주인구 수', '여성연령대 30 상주인구 수',
#        '여성연령대 40 상주인구 수', '여성연령대 50 상주인구 수', '여성연령대 60 이상 상주인구 수', '총 가구 수',
#        '아파트 가구 수', '비 아파트 가구 수', '상권 코드 명'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권 코드  총 상주인구 수  남성 상주인구 수  \
# 0     2022         4        U       관광특구  1001496        29         16
# 1     2022         4        U       관광특구  1001495      9639       4250
# 2     2022         4        U       관광특구  1001494      1977       1303
# 3     2022         4        U       관광특구  1001493      2703       1294
# 4     2022         4        U       관광특구  1001492      1089        403
#
#    여성 상주인구 수  연령대 10 상주인구 수  연령대 20 상주인구 수  ...  여성연령대 10 상주인구 수  \
# 0         13              2              4  ...                2
# 1       5389            819           2254  ...              395
# 2        674             45            218  ...               20
# 3       1409            189            626  ...              102
# 4        686             17             50  ...               10
#
#    여성연령대 20 상주인구 수  여성연령대 30 상주인구 수  여성연령대 40 상주인구 수  여성연령대 50 상주인구 수  \
# 0                2                1                2                4
# ...

# %%
df['기준_년_코드'].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017])

# %%
df2022 = df[df['기준_년_코드']==2022]
df2021 = df[df['기준_년_코드']==2021]
df2020 = df[df['기준_년_코드']==2020]
df2019 = df[df['기준_년_코드']==2019]
df2018 = df[df['기준_년_코드']==2018]
df2017 = df[df['기준_년_코드']==2017]

# %%
df2022
# Out:
#       기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권 코드  총 상주인구 수  남성 상주인구 수  \
# 0        2022         4        U       관광특구  1001496        29         16
# 1        2022         4        U       관광특구  1001495      9639       4250
# 2        2022         4        U       관광특구  1001494      1977       1303
# 3        2022         4        U       관광특구  1001493      2703       1294
# 4        2022         4        U       관광특구  1001492      1089        403
# ...       ...       ...      ...        ...      ...       ...        ...
# 6524     2022         1        A       골목상권  2110005      1796        858
# 6525     2022         1        A       골목상권  2110004       471        221
# 6526     2022         1        A       골목상권  2110003      3300       1554
# 6527     2022         1        A       골목상권  2110002       629        309
# 6528     2022         1        A       골목상권  2110001      1170        546
#
#       여성 상주인구 수  연령대 10 상주인구 수  연령대 20 상주인구 수  ...  여성연령대 10 상주인구 수  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/상권분석/상권영역.csv')
df2.head(5)
# Out:
#    기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명  엑스좌표_값  와이좌표_값  시군구_코드  \
# 0    202112        A       골목상권  2110753  시흥동 은행나무사거리  191934  438813   11545
# 1    202112        A       골목상권  2110427   노원 을지대학교병원  206265  459431   11350
# 2    202112        A       골목상권  2110755     동일여자고등학교  192300  439070   11545
# 3    202112        A       골목상권  2110739   시흥3동 우편취급국  191289  438014   11545
# 4    202112        A       골목상권  2111017     송파나루역 3번  210222  445516   11710
#
#      행정동_코드  형태정보         lat       long
# 0  11545710   NaN  126.908844  37.448687
# 1  11350611   NaN  127.070978  37.634469
# 2  11545680   NaN  126.912978  37.451006
# 3  11545690   NaN  126.901564  37.441482
# 4  11710562   NaN  127.115614  37.509060

# %%
df.head(5)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권 코드  총 상주인구 수  남성 상주인구 수  \
# 0     2022         4        U       관광특구  1001496        29         16
# 1     2022         4        U       관광특구  1001495      9639       4250
# 2     2022         4        U       관광특구  1001494      1977       1303
# 3     2022         4        U       관광특구  1001493      2703       1294
# 4     2022         4        U       관광특구  1001492      1089        403
#
#    여성 상주인구 수  연령대 10 상주인구 수  연령대 20 상주인구 수  ...  여성연령대 10 상주인구 수  \
# 0         13              2              4  ...                2
# 1       5389            819           2254  ...              395
# 2        674             45            218  ...               20
# 3       1409            189            626  ...              102
# 4        686             17             50  ...               10
#
#    여성연령대 20 상주인구 수  여성연령대 30 상주인구 수  여성연령대 40 상주인구 수  여성연령대 50 상주인구 수  \
# 0                2                1                2                4
# ...

# %%
df1 = pd.merge(df, df2[['상권_코드', 'lat', 'long']], left_on='상권 코드', right_on='상권_코드', how='left')

# %%
df1
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권 코드  총 상주인구 수  남성 상주인구 수  \
# 0         2022         4        U       관광특구  1001496        29         16
# 1         2022         4        U       관광특구  1001495      9639       4250
# 2         2022         4        U       관광특구  1001494      1977       1303
# 3         2022         4        U       관광특구  1001493      2703       1294
# 4         2022         4        U       관광특구  1001492      1089        403
# ...        ...       ...      ...        ...      ...       ...        ...
# 39173     2017         1        A       골목상권  2110005      1940        941
# 39174     2017         1        A       골목상권  2110004       534        262
# 39175     2017         1        A       골목상권  2110003      3337       1627
# 39176     2017         1        A       골목상권  2110002       680        335
# 39177     2017         1        A       골목상권  2110001      1211        574
#
# ...

# %%
df1 = df1.drop(['상권 코드', '상권_코드','상권_구분_코드'], axis=1)

# %%
df1
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드_명  총 상주인구 수  남성 상주인구 수  여성 상주인구 수  \
# 0         2022         4       관광특구        29         16         13
# 1         2022         4       관광특구      9639       4250       5389
# 2         2022         4       관광특구      1977       1303        674
# 3         2022         4       관광특구      2703       1294       1409
# 4         2022         4       관광특구      1089        403        686
# ...        ...       ...        ...       ...        ...        ...
# 39173     2017         1       골목상권      1940        941        999
# 39174     2017         1       골목상권       534        262        272
# 39175     2017         1       골목상권      3337       1627       1710
# 39176     2017         1       골목상권       680        335        345
# 39177     2017         1       골목상권      1211        574        637
#
#        연령대 10 상주인구 수  연령대 20 상주인구 수  연령대 30 상주인구 수  연령대 40 상주인구 수  ...  \
# 0                  2              4              2              4  ...
# ...

# %%
df1[df1['상권_구분_코드_명']=='관광특구']
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드_명  총 상주인구 수  남성 상주인구 수  여성 상주인구 수  \
# 0         2022         4       관광특구        29         16         13
# 1         2022         4       관광특구      9639       4250       5389
# 2         2022         4       관광특구      1977       1303        674
# 3         2022         4       관광특구      2703       1294       1409
# 4         2022         4       관광특구      1089        403        686
# ...        ...       ...        ...       ...        ...        ...
# 37545     2017         1       관광특구      6276       3069       3207
# 37546     2017         1       관광특구      2039       1290        749
# 37547     2017         1       관광특구      1928        999        929
# 37548     2017         1       관광특구      1199        431        768
# 37549     2017         1       관광특구      5653       2667       2986
#
#        연령대 10 상주인구 수  연령대 20 상주인구 수  연령대 30 상주인구 수  연령대 40 상주인구 수  ...  \
# 0                  2              4              2              4  ...
# ...

# %%
#import geopandas as gpd

# GeoJSON 파일 읽기
#gdf = gpd.read_file('/content/drive/MyDrive/상권분석/행정동_코드.geojson')

# 데이터프레임으로 변환
#df3 = pd.DataFrame(gdf)

# CSV 파일로 저장
#df3.to_csv('/content/drive/MyDrive/상권분석/행정동_코드.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-b0943c53aff6> in <cell line: 1>()
# ----> 1 import geopandas as gpd
#       2
#       3 # GeoJSON 파일 읽기
#       4 gdf = gpd.read_file('/content/drive/MyDrive/상권분석/행정동_코드.geojson')
#       5
#
# ModuleNotFoundError: No module named 'geopandas'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df2.head(5)
# Out:
#    기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드      상권_코드_명  엑스좌표_값  와이좌표_값  시군구_코드  \
# 0    202112        A       골목상권  2110753  시흥동 은행나무사거리  191934  438813   11545
# 1    202112        A       골목상권  2110427   노원 을지대학교병원  206265  459431   11350
# 2    202112        A       골목상권  2110755     동일여자고등학교  192300  439070   11545
# 3    202112        A       골목상권  2110739   시흥3동 우편취급국  191289  438014   11545
# 4    202112        A       골목상권  2111017     송파나루역 3번  210222  445516   11710
#
#      행정동_코드  형태정보         lat       long
# 0  11545710   NaN  126.908844  37.448687
# 1  11350611   NaN  127.070978  37.634469
# 2  11545680   NaN  126.912978  37.451006
# 3  11545690   NaN  126.901564  37.441482
# 4  11710562   NaN  127.115614  37.509060

# %%
df3.head()

# %%
df3 = df3.rename(columns={'adm_nm': '주소','행정동_코드':'adm_cd','adm_cd8':'행정동_코드','sidonm':'시','temp':'동','sggnm':'구','sgg':'시군구_코드'})

# %%
df3

# %%
df2['시군구_코드'] = df2['시군구_코드'].astype(str)
df3['시군구_코드'] = df3['시군구_코드'].astype(str)
df4 = pd.merge(df2, df3[['시군구_코드', '구','동']], on='시군구_코드', how='left')

# %%
df2

# %%
df4

# %%
merged_df = pd.merge(df2, df4[['기준_년월_코드', '상권_코드', '구', '동']].drop_duplicates(['기준_년월_코드', '상권_코드']), on=['기준_년월_코드', '상권_코드'], how='left')
merged_df

# %%
df5 = merged_df.drop('형태정보',axis=1)

# %%
df5

# %%
df2
# Out:
#       기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값  \
# 0       202112        A       골목상권  2110753   시흥동 은행나무사거리  191934  438813
# 1       202112        A       골목상권  2110427    노원 을지대학교병원  206265  459431
# 2       202112        A       골목상권  2110755      동일여자고등학교  192300  439070
# 3       202112        A       골목상권  2110739    시흥3동 우편취급국  191289  438014
# 4       202112        A       골목상권  2111017      송파나루역 3번  210222  445516
# ...        ...      ...        ...      ...           ...     ...     ...
# 1666    202112        U       관광특구  1001493  동대문패션타운 관광특구  200974  451975
# 1667    202112        U       관광특구  1001494    종로?청계 관광특구  199768  452273
# 1668    202112        U       관광특구  1001495       잠실 관광특구  210191  446339
# 1669    202112        U       관광특구  1001496   강남 마이스 관광특구  205310  445727
# 1670    202112        U       관광특구  1001491      이태원 관광특구  199503  448326
#
#       시군구_코드    행정동_코드  형태정보         lat       long
# ...

# %%
df6 = pd.read_excel('/content/drive/MyDrive/상권분석/KIKmix.20230501.xlsx')

# %%
df6
# Out:
#        행정동_코드    시도명 시군구명   읍면동명       법정동코드    동리명
# 0    11000000  서울특별시  NaN    NaN  1100000000  서울특별시
# 1    11110000  서울특별시  종로구    NaN  1111000000    종로구
# 2    11110515  서울특별시  종로구  청운효자동  1111010100    청운동
# 12   11110530  서울특별시  종로구    사직동  1111010600    통의동
# 24   11110540  서울특별시  종로구    삼청동  1111013900    팔판동
# ..        ...    ...  ...    ...         ...    ...
# 764  11740650  서울특별시  강동구  성내제2동  1174010800    성내동
# 765  11740660  서울특별시  강동구  성내제3동  1174010800    성내동
# 766  11740685  서울특별시  강동구     길동  1174010500     길동
# 767  11740690  서울특별시  강동구  둔촌제1동  1174010600    둔촌동
# 768  11740700  서울특별시  강동구  둔촌제2동  1174010600    둔촌동
#
# [452 rows x 6 columns]

# %%
df6
# Out:
#        행정동_코드    시도명 시군구명   읍면동명       법정동코드    동리명
# 0    11000000  서울특별시  NaN    NaN  1100000000  서울특별시
# 1    11110000  서울특별시  종로구    NaN  1111000000    종로구
# 2    11110515  서울특별시  종로구  청운효자동  1111010100    청운동
# 12   11110530  서울특별시  종로구    사직동  1111010600    통의동
# 24   11110540  서울특별시  종로구    삼청동  1111013900    팔판동
# ..        ...    ...  ...    ...         ...    ...
# 764  11740650  서울특별시  강동구  성내제2동  1174010800    성내동
# 765  11740660  서울특별시  강동구  성내제3동  1174010800    성내동
# 766  11740685  서울특별시  강동구     길동  1174010500     길동
# 767  11740690  서울특별시  강동구  둔촌제1동  1174010600    둔촌동
# 768  11740700  서울특별시  강동구  둔촌제2동  1174010600    둔촌동
#
# [452 rows x 6 columns]

# %%
df6['행정동_코드'] = df6['행정동_코드'] / 100

# %%
df6['행정동_코드'] = df6['행정동_코드'].astype(int)

# %%
merged_df = pd.merge(df2, df6, on='행정동_코드', how='left')

# %%
merged_df.to_csv('/content/drive/MyDrive/상권분석/상권영역_주소.csv', index=False)

# %%
df7 = pd.read_csv('/content/drive/MyDrive/상권분석/상권영역_주소.csv')
