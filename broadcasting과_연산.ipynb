# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/broadcasting%EA%B3%BC_%EC%97%B0%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 = pd.read_excel('/content/drive/MyDrive/python/데이터스테이션/data/E11EXAMPLE.xlsx').set_index('종목')
df2 = pd.read_excel('/content/drive/MyDrive/python/데이터스테이션/data/E11EXAMPLE.xlsx', sheet_name=1)
df1
# Out:
#          A팀    B팀   C팀    D팀    E팀
# 종목
# KT     1000   800  200     0  1200
# SK텔레콤  2000  2500    0  3000  1000
# 삼성전자    200   400  200   100   100

# %%
df2.tail(3)
# Out:
#          date   삼성전자  SK하이닉스     카카오   NAVER   삼성SDI    LG화학   SK텔레콤     KT  \
# 17 2021-06-28  81900  126000  155000  408000  679000  830000  329500  32050
# 18 2021-06-29  81000  125000  158000  411500  686000  839000  323500  31900
# 19 2021-06-30  80700  127500  163000  417500  698000  850000  320000  31800
#
#       삼성전기   LG이노텍
# 17  173500  225000
# 18  176500  222500
# 19  177000  223000

# %%
df2.iloc[-1,1:]
# Out:
# 삼성전자       80700
# SK하이닉스    127500
# 카카오       163000
# NAVER     417500
# 삼성SDI     698000
# LG화학      850000
# SK텔레콤     320000
# KT         31800
# 삼성전기      177000
# LG이노텍     223000
# Name: 19, dtype: object

# %%
df1.mul(df2.iloc[-1,1:], axis=0).dropna()# .to_clipboard
# Out:
#                 A팀           B팀          C팀           D팀           E팀
# KT      31800000.0   25440000.0   6360000.0          0.0   38160000.0
# SK텔레콤  640000000.0  800000000.0         0.0  960000000.0  320000000.0
# 삼성전자    16140000.0   32280000.0  16140000.0    8070000.0    8070000.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)
