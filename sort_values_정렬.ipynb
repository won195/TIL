# %% [markdown]
# <a href="https://colab.research.google.com/github/won195/TIL/blob/master/sort_values_%EC%A0%95%EB%A0%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 = pd.read_excel('/content/drive/MyDrive/python/데이터스테이션/data/E10EXAMPLE.xlsx')
df1
# Out:
#       이름   점수    나이
# 0    문학진  100  26.1
# 1    김도현  100  61.4
# 2    배호근   89  62.5
# 3    고세원   76  60.3
# 4    권오영   62  20.5
# ..   ...  ...   ...
# 195  권오성   91  36.7
# 196  김광영   98  68.0
# 197  구성환   87  34.2
# 198  박준목   73  52.6
# 199  박영준   97  45.8
#
# [200 rows x 3 columns]

# %%
df1['정렬'] = df1['나이'].mask(df1['나이']<60, 0)
df1 = df1.sort_values(['점수','정렬','나이'], ascending=[0,0,1])
df1.drop('정렬', axis=1)# .to_clipboard(index=False)
# Out:
#       이름   점수    나이
# 1    김도현  100  61.4
# 0    문학진  100  26.1
# 93   민찬기  100  46.5
# 69   박천국  100  52.4
# 91   박선웅   99  63.1
# ..   ...  ...   ...
# 18   백종민   61  54.2
# 32   류주한   61  54.3
# 123  강창묵   60  31.8
# 71   기도훈   60  46.7
# 45   김사권   60  50.1
#
# [200 rows x 3 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
